# %% [markdown]
# # Lab Week 4
# In this lab, we experiment how KNN works.
#
# ### Dataset
# Let's considet the Titanic dataset available on:
# https://github.com/andvise/DataAnalyticsDatasets/blob/main/titanic.csv

# %%
import pandas as pd
df = pd.read_csv("https://github.com/andvise/DataAnalyticsDatasets/blob/dc74027bd063510ede437e4d612f41eb078e49b9/titanic.csv?raw=true")
df.dtypes
# Out:
# PassengerId                  int64
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard    float64
# Fare                       float64
# dtype: object

# %% [markdown]
# Replace the missing values with 0.

# %%
df = df.fillna(0)

# %% [markdown]
# The goal is to predict if you would have survived the Titanic accident.
#
# Create a Pandas Series containing your personal data (feel free to use random values).

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
my_data = pd.Series([999, 1, 2, 'Andrea', 'male', 18, 1, 0, 25], index= ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
       'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Fare'])

# %%
col_relevant = [ 'Pclass', 'Age', 'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Fare']

df_diff = df[col_relevant] - my_data[col_relevant]

# %%
df_diff = abs(df_diff)
distances = df_diff.sum(axis=1).sort_values()
k = 7
distances.head(k).index
# Out:
# Index([543, 424, 648, 787, 135, 421, 314], dtype='int64')

# %%
df.iloc[distances.head(k).index, 1].mode()
# Out:
# 0    1
# Name: Survived, dtype: int64

# %% [markdown]
# To classify yourself consider your closest neighbour according to the numerical columns. Which columns should you consider?

# %%
df.sort_values(by='Age')

## YOUR CODE HERE
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 799          800         1       3       Master. Assad Alexander Thomas
# 751          752         1       2             Master. Viljo Hamalainen
# 641          642         1       3                Miss. Eugenie Baclini
# 466          467         1       3         Miss. Helene Barbara Baclini
# 77            78         1       2         Master. Alden Gates Caldwell
# ..           ...       ...     ...                                  ...
# 115          116         0       3                  Mr. Patrick Connors
# 490          491         0       1               Mr. Ramon Artagaveytia
# 95            96         0       1             Mr. George B Goldschmidt
# 847          848         0       3                   Mr. Johan Svensson
# 627          628         1       1  Mr. Algernon Henry Wilson Barkworth
#
#         Sex    Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# Subtract the selected columns from the dataframe.

# %%
df.sample(1).index
# Out:
# Index([829], dtype='int64')

# %% [markdown]
# Find which index has the closest Manhattan Distance.

# %%
## YOUR CODE HERE

# %% [markdown]
# Check if the person on that index survived or not.

# %%
## YOUR CODE HERE
